# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
original_img = cv2.imread('/usercode/images/cans/diced_tomatoes_noise.jpg')

# Display the original image
plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))  # matplotlib expects RGB images

# %%
# Blur the image with a uniform 7x7 kernel
blurred_img = None
plt.imshow(cv2.cvtColor(blurred_img, cv2.COLOR_BGR2RGB))

# %%
# Split the blurred image in the 3 channels, B, G, R
blue_img, green_img, red_img = None, None, None

# Threshold the blue channel with a threshold of 80
retval, thresholded_blue_img = None, None

# Threshold the red channel with a threshold of 80
retval, thresholded_red_img = None, None

# %%
# Union of the blue and the red masks
mask = None

# Display the mask
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR))

# %%
# Mask the original image. Don't forget to convert the mask to BGR, such that the two input images have the same shape.
masked_cans_img = None

# Display the masked cans
plt.imshow(cv2.cvtColor(masked_cans_img, cv2.COLOR_BGR2RGB))
